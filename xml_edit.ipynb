# %%
from PIL import Image
import numpy as np
import cv2
import matplotlib.pyplot as plt
import shutil
import os
import time

# %%
path = 'C:/Users/User/Desktop/Ablaufdatum/ablaufdatum_selber'
path_cyg = '/cygdrive/c/Users/User/Desktop/Ablaufdatum/ablaufdatum_selber'
files_all_original_size = !ls {path_cyg}/all_windowed
anzahl_original_size = len(files_all_original_size)
w_size = 512 #window size

# %%
if anzahl_original_size > 0:
    for i in range(0, anzahl_original_size):
        with open(path + '/all_windowed/' + files_all_original_size[0], "a") as file:
            file.replace("500", "512")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-27b978d09d7a> in <module>()
#       2     for i in range(0, anzahl_original_size):
#       3         with open(path + '/all_windowed/' + files_all_original_size[0], "a") as file:
# ----> 4             file.replace("500", "512")
#       5
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'replace'

# %%
print('Anzahl xml files ', i+1)
# Out:
# Anzahl xml files  287

# %%
# !ls {path}/all_windowed
# Out:
# 20180528_200104.jpg
# 20180528_200131.jpg
# 20180529_160952.jpg
# 20180529_214836.jpg
# 20180529_214925.jpg
# 20180529_215048.jpg
# 20180529_215113.jpg
# 20180529_215141.jpg
# 20180529_215258.jpg
# 20180529_215507.jpg
# 20180529_215613.jpg
# 20180529_215637.jpg
# 20180529_215801.jpg
# 20180529_215937.jpg
# 20180529_220039.jpg
# 20180529_220107.jpg
# 20180602_115536.jpg
# 20180602_115610.jpg
# 20180602_115629.jpg
# 20180602_115645.jpg
# 20180602_115704.jpg
# 20180602_115714.jpg
# 20180602_115727.jpg
# 20180602_115743.jpg
# 20180602_115752.jpg
# 20180602_115842.jpg
# 20180602_115853.jpg
# 20180602_115905.jpg
# 20180602_115914.jpg
# 20180602_115936.jpg
# 20180602_123423.jpg
# 20180602_123442.jpg
# 20180602_123527.jpg
# 20180602_123541.jpg
# 20180602_124101.jpg
# 20180602_131349.jpg
# 20180602_131353.jpg
# 20180602_131403.jpg
# 20180602_131406.jpg
# 20180602_131437.jpg
# 20180602_131439.jpg
# 20180602_131504.jpg
# 20180602_131507.jpg
# 20180602_131519.jpg
# 20180602_131522.jpg
# ...

# %%
# files muss mit path_cyg initalisiert werden sonst Fehler (komisch)
files_all = !ls {path_cyg}/all_windowed

# %%
files_all[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-409d5dfe1720> in <module>()
# ----> 1 files_all[0]
#
# NameError: name 'files_all' is not defined

# %%
# Out:
# path + '/all_windowed/' + files_all_original_size[0]

# %%
print(files_all_original_size[0])
# Out:
# 20180528_200104.xml

# %%
file_name = files_all_original_size[0]
print(file_name)
# Out:
# 20180528_200104.xml

# %%
fp = open(path + '/all_windowed/' + files_all_original_size[0], 'r', encoding='UTF-8')
print(fp)
# Out:
# <_io.TextIOWrapper name='C:/Users/User/Desktop/Ablaufdatum/ablaufdatum_selber/all_windowed/20180528_200104.xml' mode='r' encoding='UTF-8'>
